# %%
import numpy as np
import pandas as pd
x=pd.read_csv("C:/Users/hemap/Downloads/Paper2/credit_card.csv")
df=pd.DataFrame(x)
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df=df.drop('CUST_ID',axis=1)

# %% [markdown]
# ## What does the primary analysis of several categorical features reveal?

# %% [markdown]
# #### In the given dataset only one categorical value exist that is cust_id,which is useful for the identification of credit card holder.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### a. Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
a=df['MINIMUM_PAYMENTS'].mean()
df['MINIMUM_PAYMENTS'].fillna(a,inplace=True)

# %%
a=df['CREDIT_LIMIT'].mean()
df['CREDIT_LIMIT'].fillna(a,inplace=True)

# %%
df.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
# ...

# %% [markdown]
# ### b. Outlier Treatment using the Z-score method

# %%
import matplotlib.pyplot as plt
for i in df:
    plt.boxplot(df[i])
    plt.show()

# %%
from scipy.stats import zscore
for i in df:
    df['zscore']=(df[i]-df[i].mean())/df[i].std()
    df[df['zscore']>3]
    df[df['zscore']<-3]
    df_new=df[(df.zscore>-3) & (df.zscore<3)]
    print(df_new)
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %% [markdown]
# ## c. Deal with correlated variables

# %%
df.corr().style.background_gradient(cmap="coolwarm")

# %% [markdown]
# ## Perform dimensionality reduction using PCA such that the 95% of the variance is explained

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc_pca=sc.fit_transform(df)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 4)
principal_comp = pca.fit_transform(df)
principal_comp

# %%
principal_comp.shape
# Out:
# (8950, 4)

# %% [markdown]
# ## Q4. Find the optimum value of k for k-means clustering using the elbow method. Plot the elbow curv

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.cluster import KMeans
km=KMeans(n_clusters=7,random_state=42)
km.fit_predict(x)

# %%
wcss=[]
for i in range(2,7):
    kmeans=KMeans(n_clusters=i,init='k-means++',n_init=10,max_iter=300,tol=0.0001,verbose=0,random_state=None,copy_x=True,algorithm='auto')
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)

# %%
import matplotlib.pyplot as plt
plt.plot(range(2,7),wcss)

# %% [markdown]
# ## From the above graph I found that optimal number of cluster using elbow method is 3

# %% [markdown]
# ### Q5. Find the optimum value of k for k-means clustering using the silhouette score method and specify the number of 3observations in each cluster using a bar plot

# %%
import sklearn.metrics as metrics
for i in range(2,7):
    kmeans=KMeans(n_clusters=i,init="k-means++",random_state=200)
    kmeans.fit(df)
    labels=kmeans.labels_
    print("Silhouette  score for k(clusters)="+str(i)+" is "+str(metrics.silhouette_score(df,labels,metric="euclidean",sample_size=1000,random_state=200)))

# %% [markdown]
# ## From the above observation using silhouette score method optimal number of cluster is found to be 2

# %%
import matplotlib.pyplot as plt
import yellowbrick
from yellowbrick.cluster import SilhouetteVisualizer
fig,ax=plt.subplots(2,2,figsize=(15,3))
for i in [2,3,4,5]:
    #create kmeans instance for different number of clusters
    km=KMeans(n_clusters=i,init='k-means++',n_init=10,max_iter=100,random_state=42)
    q,mod=divmod(i,2)
    #create silhoueteevisualizer instance with kmeans instance
    #fit the visualizer
    visualizer=SilhouetteVisualizer(km,colors='yellowbrick',ax=ax[q-1][mod])
    visualizer.fit(x)
